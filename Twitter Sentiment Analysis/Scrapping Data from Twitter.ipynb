# %% [markdown]
# # Εισαγωγικά

# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy
import pandas as pd

# %%
#Authentication
consumer_key = 'ZMMjkS37qTi9vuXsetoKbOGfP'
consumer_secret = 'eWdB2hAqm3hdkL3FhbKALAbtAViAEGAt7PIrIDXYGTBJcn44h8'
access_token = '1588836299200512000-spyB54fqpBesHUwDHOwRQWekIc33Se'
access_token_secret = '4OrK6v0GdVmzuyOWIlCN4FHbbfgRoU3E5soH9xIXhZpmO'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
#Get all tweets from any user
id = 'elonmusk'
new_tweets = api.user_timeline(screen_name = id,count=20)
print(len(new_tweets))
print(new_tweets)
# Out:
# 20
# ...

# %%
import json
tweets = []
for tw in new_tweets:
    tweets.append(tw.text)
print(tweets)
# Out:
# ['@BLKMDL3 @DirtyTesLa @WholeMarsBlog Rollout will broaden roughly every week', '@ID_AA_Carmack Fond memories', '@TaraBull808 🤣💯', '@WholeMarsBlog @saasInvestor Ok …', '@DirtyTesLa @WholeMarsBlog Probably next month', '@DirtyTesLa @WholeMarsBlog Going without saying that we all want ASS (Actually Smart Summon) ASAP!!', '@slashdot No way', '@debarghya_das @ayushkhd @Tesla Making Tesla Superchargers &amp; connectors available to all is the right thing to do', '@A_MrBenMitchell @RadioShack @MarioNawfal Spaces should be evolve. It has potential to be truly great.', '@pauljamil @philbak1 Probably end of next week', '@philbak1 My reaction to SBF was … different', '@MarioNawfal Twitter at its best!', '@alex_avoigt 💪💪', '@ashleevance @mtaibbi @joerogan Twitter drives a massive number of clicks to other websites/apps. Biggest click dri… https://t.co/wEMEL9SObg', '@kellymilkies @tomasverdugo @balinares 🎯', '@elephantbridge @balinares Yes', '@balinares This is false. Anyone who can be in office
# ...

# %%
#Cleaner display
df_tweets = pd.DataFrame(tweets)
df_tweets
# Out:
#                                                     0
# 0   @BLKMDL3 @DirtyTesLa @WholeMarsBlog Rollout wi...
# 1                        @ID_AA_Carmack Fond memories
# 2                                     @TaraBull808 🤣💯
# 3                   @WholeMarsBlog @saasInvestor Ok …
# 4      @DirtyTesLa @WholeMarsBlog Probably next month
# 5   @DirtyTesLa @WholeMarsBlog Going without sayin...
# 6                                    @slashdot No way
# 7   @debarghya_das @ayushkhd @Tesla Making Tesla S...
# 8   @A_MrBenMitchell @RadioShack @MarioNawfal Spac...
# 9      @pauljamil @philbak1 Probably end of next week
# 10       @philbak1 My reaction to SBF was … different
# 11                  @MarioNawfal Twitter at its best!
# 12                                    @alex_avoigt 💪💪
# 13  @ashleevance @mtaibbi @joerogan Twitter drives...
# 14           @kellymilkies @tomasverdugo @balinares 🎯
# 15                     @elephantbridge @balinares Yes
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
sid = SentimentIntensityAnalyzer()

# %%
# Extracting tweets with a hashtag

htag = '#Covid19'
tweets = []
for tw in tweepy.Cursor(api.search,q=htag).items(100):

    tweets.append(tw.text)
    print(tw)
scores = []
for tw in tweets:
    print(tw)
    score = sid.polarity_scores(tw)
    scores.append(score)
    print(score)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df = pd.DataFrame(scores)
df
# Out:
#       neg    neu    pos  compound
# 0   0.000  1.000  0.000    0.0000
# 1   0.000  1.000  0.000    0.0000
# 2   0.000  1.000  0.000    0.0000
# 3   0.000  0.831  0.169    0.6240
# 4   0.000  1.000  0.000    0.0000
# ..    ...    ...    ...       ...
# 95  0.099  0.901  0.000   -0.3182
# 96  0.000  1.000  0.000    0.0000
# 97  0.000  1.000  0.000    0.0000
# 98  0.000  1.000  0.000    0.0000
# 99  0.000  1.000  0.000    0.0000
#
# [100 rows x 4 columns]

# %% [markdown]
# # Project 3 - Scrapping Data

# %%
import tweepy
import pandas as pd

# %%
#Authentication
consumer_key = 'ZMMjkS37qTi9vuXsetoKbOGfP'
consumer_secret = 'eWdB2hAqm3hdkL3FhbKALAbtAViAEGAt7PIrIDXYGTBJcn44h8'
access_token = '1588836299200512000-spyB54fqpBesHUwDHOwRQWekIc33Se'
access_token_secret = '4OrK6v0GdVmzuyOWIlCN4FHbbfgRoU3E5soH9xIXhZpmO'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
import json

# %%
htag = '#Covid19'
tweets = []
for tw in tweepy.Cursor(api.search,q=htag).items(10):
    tweets.append(tw.text)
    print(tw)
# Out:
# Status(_api=<tweepy.api.API object at 0x7f5818f0b5d0>, _json={'created_at': 'Fri Nov 11 08:00:24 +0000 2022', 'id': 1590977729822101509, 'id_str': '1590977729822101509', 'text': 'RT @WEDO_worldwide: 4⃣ End the sovereign debt crisis &amp; promote #DebtJustice. Redirect public resources from servicing predatory, illegitima…', 'truncated': False, 'entities': {'hashtags': [{'text': 'DebtJustice', 'indices': [67, 79]}], 'symbols': [], 'user_mentions': [{'screen_name': 'WEDO_worldwide', 'name': 'WEDO', 'id': 22977061, 'id_str': '22977061', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 176591537, 'id_str': '176591537', 'name': 'Feminist Task Force', 'screen_name': 'femt
# ...

# %%
tweets
# Out:
# ['RT @WEDO_worldwide: 4⃣ End the sovereign debt crisis &amp; promote #DebtJustice. Redirect public resources from servicing predatory, illegitima…',
#  '#検査と隔離は感染制御の基本 #covid19 #PCR #変異株 #自己防衛  #SARSCoV2 \nCOVID19（全国）11月11日  \n陽性件数 74,093件\n重症者件数210件\n死亡件数 81件\n要入院件数517,37… https://t.co/vL4ESAFhcO',
#  'RT @RoryBurnside: Did WA get the timing of their border reopening right earlier this year or did they get it wrong? Please vote and retweet…',
#  'RT @jfpoisson78: On a trouvé la dernière personne au monde qui croit que le vaccin empêche d’attraper la Covid et de la transmettre. Malheu…',
#  'Aktuell aus der Stadt #Flensburg am 10.11.2022:\n\nFälle neu: 46\nFälle kumulativ: 38201\n7-Tage-Inzidenz: 316.1\n\nVerst… https://t.co/XTUcAnHvn4',
#  'RT @Badrsalrajhi: #بدر_صالح_الراجحي #badr_alrajhi #AD #anime #AU #CE #China #COVID19 #jp #MX #Quran #RC #RK #rose #TikTok #UK #USA https://…',
# ...

# %%
hashtag_tweets = tweepy.Cursor(api.search, q="#Covid19", tweet_mode='extended', lang="en", wait_on_rate_limit=True).items(50000)
tweets = []
tweet_point = []
for tweet in hashtag_tweets:
    username = tweet.author.screen_name
    text = tweet.full_text
    tweet_point = [username , text]
    tweets.append(tweet_point)

# %%
df = pd.DataFrame(tweets, columns=['User', 'Tweet'])

# %%
df
# Out:
#                  User                                              Tweet
# 0       AuroraAldmora  RT @potcalling: #CovidIsNotOver #COVID19 \n\nT...
# 1        MogesMoges19  RT @DrTedros: The number of weekly reported #C...
# 2        DailyLeadPak  41 tested positive due to COVID-19 in last 24 ...
# 3       TheEducatorAU  Today, NSW Chief Health Officer Dr Kerry Chant...
# 4      alessandro5161  Is the Italian Government ready for the next c...
# ...               ...                                                ...
# 49995   BurnitonSkido  RT @AflaoGodigbeza: THIS IS AFLAO!!!\n\n#Aflao...
# 49996     COVID_Scale  Since the start of the pandemic, 1,098,235 Ame...
# 49997   COVID_LDS_Bot  How is everyone doing? #COVID #westyorkshire #...
# 49998      ToshiAkima  RT @drbecs: Only 3 other people masking in sho...
# 49999     MilletEater  RT @drbecs: Only 3 other people masking in sho...
#
# [50000 rows x 2 columns]

# %%
from  google.colab  import  drive 
drive.mount ( '/content/drive' )
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/MyDrive/ΠΕΠ/Project 3/CovidTweets.csv')
